# %% [markdown]
# # 0. Import

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
import os

# %% [markdown]
# # 1. Authentication

# %%
gauth = GoogleAuth()
gauth.LocalWebserverAuth()
drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=520354908574-r9ari5kt54jtksob3eb6c1d81r618e50.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %% [markdown]
# # 2. Download  Files

# %%
def download_file_recursively( parent_id, dst_dir):
        os.makedirs(dst_dir, exist_ok=True)

        file_list = drive.ListFile({'q': '"{}" in parents and trashed = false'.format(parent_id)}).GetList()

        for f in file_list:
            if f['mimeType'] == 'application/vnd.google-apps.folder':
                download_file_recursively( f['id'], os.path.join(dst_dir, f['title']))
            else:
                dst_path = os.path.join(dst_dir, f['title'])
                f.GetContentFile(dst_path)
                print('Download {} to {}'.format(f['title'], dst_path))

# %% [markdown]
# Check root dir in Google Drive

# %%
file_list = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()
for file1 in file_list:
  print('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: data, id: 1oLpYoKAqBY8eyBWPi7A9YRFKhjqyGWWY
# title: .ipynb_checkpoints, id: 1-JzFJwsVdurN7bSCCiwUkrQ5LcG7tHb2
# title: Colab Notebooks, id: 1MKCWykhAwsYMv49ANJmGwD5V_Ncn1TDU

# %% [markdown]
# Check content in data dir

# %%
folder_id = drive.ListFile({'q': "title = 'data'"}).GetList()[0]['id']
file_list = drive.ListFile({'q': '"{}" in parents and trashed = false'.format(folder_id)}).GetList()
for file1 in file_list:
  print('title: %s, id: %s' % (file1['title'], file1['id']))
# Out:
# title: pahts_list.csv, id: 1yiIPPXVx4NdcRuF4aFtz2R750QuC9aCB
# title: cifar-10, id: 1h_zZRg2pnoCuo0ctOdv5sPjyO2i74In4
# title: generated_data, id: 16ozFYpnMJ5QH1MPjTNKWU-uEO0ceh-m0

# %%
download_file_recursively( folder_id, 'data')
# Out:
# Download pahts_list.csv to data/pahts_list.csv
# Download 49742.png to data/cifar-10/train/cat/49742.png
# Download 49146.png to data/cifar-10/train/cat/49146.png
# Download 49081.png to data/cifar-10/train/cat/49081.png
# Download 49602.png to data/cifar-10/train/cat/49602.png
# Download 49618.png to data/cifar-10/train/cat/49618.png
# Download 49142.png to data/cifar-10/train/cat/49142.png
# Download 49443.png to data/cifar-10/train/cat/49443.png
# Download 49918.png to data/cifar-10/train/cat/49918.png
# Download 49078.png to data/cifar-10/train/cat/49078.png
# Download 49646.png to data/cifar-10/train/cat/49646.png
# Download 49140.png to data/cifar-10/train/cat/49140.png
# Download 49197.png to data/cifar-10/train/cat/49197.png
# Download 49855.png to data/cifar-10/train/cat/49855.png
# Download 49872.png to data/cifar-10/train/cat/49872.png
# Download 49299.png to data/cifar-10/train/cat/49299.png
# Download 49900.png to data/cifar-10/train/cat/49900.png
# Download 49840.png to data/cifar-10/train/cat/49840.png
# Download 49691.png to data/cifar-10/train/cat/49691.png
# Download 49819.png to data/cifar-10/train/cat/49819.png
# Download 49298.png to data/cifar-10/train/cat/49298.png
# Download 49478.png to data/cifar-10/train/cat/49478.png
# Download 49366.png to data/cifar-10/train/cat/49366.png
# Download 49958.png to data/cifar-10/train/cat/49958.png
# Download 49233.png to data/cifar-10/train/cat/49233.png
# Download 49839.png to data/cifar-10/train/cat/49839.png
# Download 49143.png to data/cifar-10/train/cat/49143.png
# Download 49079.png to data/cifar-10/train/cat/49079.png
# Download 49468.png to data/cifar-10/train/cat/49468.png
# Download 49444.png to data/cifar-10/train/cat/49444.png
# Download 49790.png to data/cifar-10/train/cat/49790.png
# Download 49770.png to data/cifar-10/train/cat/49770.png
# Download 49822.png to data/cifar-10/train/cat/49822.png
# Download 49083.png to data/cifar-10/train/cat/49083.png
# Download 49131.png to data/cifar-10/train/cat/49131.png
# Download 49786.png to data/cifar-10/train/cat/49786.png
# Download 49832.png to data/cifar-10/train/cat/49832.png
# Download 49240.png to data/cifar-10/train/cat/49240.png
# Download 49934.png to data/cifar-10/train/cat/49934.png
# Download 49222.png to data/cifar-10/train/cat/49222.png
# Download 49807.png to data/cifar-10/train/cat/49807.png
# Download 49500.png to data/cifar-10/train/cat/49500.png
# Download 49773.png to data/cifar-10/train/cat/49773.png
# Download 49386.png to data/cifar-10/train/cat/49386.png
# Download 49626.png to data/cifar-10/train/cat/49626.png
# Download 49178.png to data/cifar-10/train/cat/49178.png
# Download 49322.png to data/cifar-10/train/cat/49322.png
# Download 49600.png to data/cifar-10/train/cat/49600.png
# Download 49408.png to data/cifar-10/train/cat/49408.png
# Download 49792.png to data/cifar-10/train/cat/49792.png
# Download 49775.png to data/cifar-10/train/cat/49775.png
# Download 49368.png to data/cifar-10/train/cat/49368.png
# Download 49619.png to data/cifar-10/train/cat/49619.png
# Download 49982.png to data/cifar-10/train/cat/49982.png
# Download 49054.png to data/cifar-10/train/cat/49054.png
# Download 49574.png to data/cifar-10/train/cat/49574.png
# Download 49544.png to data/cifar-10/train/cat/49544.png
# Download 49499.png to data/cifar-10/train/cat/49499.png
# Download 49668.png to data/cifar-10/train/cat/49668.png
# Download 49563.png to data/cifar-10/train/cat/49563.png
# Download 49609.png to data/cifar-10/train/cat/49609.png
# Download 49481.png to data/cifar-10/train/cat/49481.png
# Download 49835.png to data/cifar-10/train/cat/49835.png
# Download 49190.png to data/cifar-10/train/cat/49190.png
# Download 49319.png to data/cifar-10/train/cat/49319.png
# Download 49170.png to data/cifar-10/train/cat/49170.png
# Download 49940.png to data/cifar-10/train/cat/49940.png
# Download 49117.png to data/cifar-10/train/cat/49117.png
# Download 49614.png to data/cifar-10/train/cat/49614.png
# Download 49218.png to data/cifar-10/train/cat/49218.png
# Download 49741.png to data/cifar-10/train/cat/49741.png
# Download 49448.png to data/cifar-10/train/cat/49448.png
# Download 49692.png to data/cifar-10/train/cat/49692.png
# Download 49463.png to data/cifar-10/train/cat/49463.png
# Download 49280.png to data/cifar-10/train/cat/49280.png
# Download 49922.png to data/cifar-10/train/cat/49922.png
# Download 49306.png to data/cifar-10/train/cat/49306.png
# Download 49492.png to data/cifar-10/train/cat/49492.png
# Download 49424.png to data/cifar-10/train/cat/49424.png
# Download 49384.png to data/cifar-10/train/cat/49384.png
# Download 49726.png to data/cifar-10/train/cat/49726.png
# Download 49906.png to data/cifar-10/train/cat/49906.png
# Download 49223.png to data/cifar-10/train/cat/49223.png
# Download 49632.png to data/cifar-10/train/cat/49632.png
# Download 49825.png to data/cifar-10/train/cat/49825.png
# Download 49157.png to data/cifar-10/train/cat/49157.png
# Download 49901.png to data/cifar-10/train/cat/49901.png
# Download 49089.png to data/cifar-10/train/cat/49089.png
# Download 49762.png to data/cifar-10/train/cat/49762.png
# Download 49970.png to data/cifar-10/train/cat/49970.png
# Download 49466.png to data/cifar-10/train/cat/49466.png
# Download 49713.png to data/cifar-10/train/cat/49713.png
# Download 49983.png to data/cifar-10/train/cat/49983.png
# Download 49325.png to data/cifar-10/train/cat/49325.png
# Download 49979.png to data/cifar-10/train/cat/49979.png
# Download 49430.png to data/cifar-10/train/cat/49430.png
# Download 49273.png to data/cifar-10/train/cat/49273.png
# Download 49582.png to data/cifar-10/train/cat/49582.png
# Download 49576.png to data/cifar-10/train/cat/49576.png
# Download 49975.png to data/cifar-10/train/cat/49975.png
# Download 49599.png to data/cifar-10/train/cat/49599.png
# Download 49367.png to data/cifar-10/train/cat/49367.png
# Download 49944.png to data/cifar-10/train/cat/49944.png
# Download 49336.png to data/cifar-10/train/cat/49336.png
# Download 49701.png to data/cifar-10/train/cat/49701.png
# Download 49227.png to data/cifar-10/train/cat/49227.png
# Download 49545.png to data/cifar-10/train/cat/49545.png
# Download 49791.png to data/cifar-10/train/cat/49791.png
# Download 49896.png to data/cifar-10/train/cat/49896.png
# Download 48062.png to data/cifar-10/train/cat/48062.png
# Download 48931.png to data/cifar-10/train/cat/48931.png
# Download 48907.png to data/cifar-10/train/cat/48907.png
# Download 48592.png to data/cifar-10/train/cat/48592.png
# Download 47915.png to data/cifar-10/train/cat/47915.png
# Download 48933.png to data/cifar-10/train/cat/48933.png
# Download 47840.png to data/cifar-10/train/cat/47840.png
# Download 48993.png to data/cifar-10/train/cat/48993.png
# Download 47942.png to data/cifar-10/train/cat/47942.png
# Download 48517.png to data/cifar-10/train/cat/48517.png
# Download 48037.png to data/cifar-10/train/cat/48037.png
# Download 47812.png to data/cifar-10/train/cat/47812.png
# Download 48601.png to data/cifar-10/train/cat/48601.png
# Download 48157.png to data/cifar-10/train/cat/48157.png
# Download 47838.png to data/cifar-10/train/cat/47838.png
# Download 48540.png to data/cifar-10/train/cat/48540.png
# Download 48144.png to data/cifar-10/train/cat/48144.png
# Download 48183.png to data/cifar-10/train/cat/48183.png
# Download 48609.png to data/cifar-10/train/cat/48609.png
# Download 48719.png to data/cifar-10/train/cat/48719.png
# Download 48946.png to data/cifar-10/train/cat/48946.png
# Download 47997.png to data/cifar-10/train/cat/47997.png
# Download 48426.png to data/cifar-10/train/cat/48426.png
# Download 48162.png to data/cifar-10/train/cat/48162.png
# Download 48058.png to data/cifar-10/train/cat/48058.png
# Download 47775.png to data/cifar-10/train/cat/47775.png
# Download 48880.png to data/cifar-10/train/cat/48880.png
# Download 48233.png to data/cifar-10/train/cat/48233.png
# Download 48377.png to data/cifar-10/train/cat/48377.png
# Download 49044.png to data/cifar-10/train/cat/49044.png
# Download 48776.png to data/cifar-10/train/cat/48776.png
# Download 47995.png to data/cifar-10/train/cat/47995.png
# Download 47963.png to data/cifar-10/train/cat/47963.png
# Download 48536.png to data/cifar-10/train/cat/48536.png
# Download 48494.png to data/cifar-10/train/cat/48494.png
# Download 47848.png to data/cifar-10/train/cat/47848.png
# Download 48028.png to data/cifar-10/train/cat/48028.png
# Download 47897.png to data/cifar-10/train/cat/47897.png
# Download 47950.png to data/cifar-10/train/cat/47950.png
# Download 48849.png to data/cifar-10/train/cat/48849.png
# Download 48443.png to data/cifar-10/train/cat/48443.png
# Download 48007.png to data/cifar-10/train/cat/48007.png
# Download 48742.png to data/cifar-10/train/cat/48742.png
# Download 48019.png to data/cifar-10/train/cat/48019.png
# Download 48543.png to data/cifar-10/train/cat/48543.png
# Download 47901.png to data/cifar-10/train/cat/47901.png
# Download 48914.png to data/cifar-10/train/cat/48914.png
# Download 49032.png to data/cifar-10/train/cat/49032.png
# Download 48966.png to data/cifar-10/train/cat/48966.png
# Download 48331.png to data/cifar-10/train/cat/48331.png
# Download 48390.png to data/cifar-10/train/cat/48390.png
# Download 48952.png to data/cifar-10/train/cat/48952.png
# Download 48248.png to data/cifar-10/train/cat/48248.png
# Download 48063.png to data/cifar-10/train/cat/48063.png
# Download 47819.png to data/cifar-10/train/cat/47819.png
# Download 48346.png to data/cifar-10/train/cat/48346.png
# Download 47830.png to data/cifar-10/train/cat/47830.png
# Download 47902.png to data/cifar-10/train/cat/47902.png
# Download 48243.png to data/cifar-10/train/cat/48243.png
# Download 48928.png to data/cifar-10/train/cat/48928.png
# Download 48524.png to data/cifar-10/train/cat/48524.png
# Download 48629.png to data/cifar-10/train/cat/48629.png
# Download 48402.png to data/cifar-10/train/cat/48402.png
# Download 48999.png to data/cifar-10/train/cat/48999.png
# Download 48957.png to data/cifar-10/train/cat/48957.png
# Download 48830.png to data/cifar-10/train/cat/48830.png
# Download 47823.png to data/cifar-10/train/cat/47823.png
# Download 47797.png to data/cifar-10/train/cat/47797.png
# Download 47788.png to data/cifar-10/train/cat/47788.png
# Download 48409.png to data/cifar-10/train/cat/48409.png
# Download 48052.png to data/cifar-10/train/cat/48052.png
# Download 47741.png to data/cifar-10/train/cat/47741.png
# Download 48376.png to data/cifar-10/train/cat/48376.png
# Download 48088.png to data/cifar-10/train/cat/48088.png
# Download 48134.png to data/cifar-10/train/cat/48134.png
# Download 48262.png to data/cifar-10/train/cat/48262.png
# Download 47736.png to data/cifar-10/train/cat/47736.png
# Download 48085.png to data/cifar-10/train/cat/48085.png
# Download 48200.png to data/cifar-10/train/cat/48200.png
# Download 49009.png to data/cifar-10/train/cat/49009.png
# Download 48758.png to data/cifar-10/train/cat/48758.png
# Download 48867.png to data/cifar-10/train/cat/48867.png
# Download 47866.png to data/cifar-10/train/cat/47866.png
# Download 48834.png to data/cifar-10/train/cat/48834.png
# Download 48808.png to data/cifar-10/train/cat/48808.png
# Download 47998.png to data/cifar-10/train/cat/47998.png
# Download 48507.png to data/cifar-10/train/cat/48507.png
# Download 48814.png to data/cifar-10/train/cat/48814.png
# Download 48039.png to data/cifar-10/train/cat/48039.png
# Download 47851.png to data/cifar-10/train/cat/47851.png
# Download 48768.png to data/cifar-10/train/cat/48768.png
# Download 48118.png to data/cifar-10/train/cat/48118.png
# Download 48131.png to data/cifar-10/train/cat/48131.png
# Download 48186.png to data/cifar-10/train/cat/48186.png
# Download 48638.png to data/cifar-10/train/cat/48638.png
# Download 48846.png to data/cifar-10/train/cat/48846.png
# Download 48005.png to data/cifar-10/train/cat/48005.png
# Download 48506.png to data/cifar-10/train/cat/48506.png
# Download 48912.png to data/cifar-10/train/cat/48912.png
# Download 47970.png to data/cifar-10/train/cat/47970.png
# Download 48561.png to data/cifar-10/train/cat/48561.png
# Download 48762.png to data/cifar-10/train/cat/48762.png
# Download 48296.png to data/cifar-10/train/cat/48296.png
# Download 48722.png to data/cifar-10/train/cat/48722.png
# Download 48798.png to data/cifar-10/train/cat/48798.png
# Download 48909.png to data/cifar-10/train/cat/48909.png
# Download 48479.png to data/cifar-10/train/cat/48479.png
# Download 48452.png to data/cifar-10/train/cat/48452.png
# Download 48686.png to data/cifar-10/train/cat/48686.png
# Download 47982.png to data/cifar-10/train/cat/47982.png
# Download 47933.png to data/cifar-10/train/cat/47933.png
# Download 48112.png to data/cifar-10/train/cat/48112.png
# Download 48614.png to data/cifar-10/train/cat/48614.png
# Download 47801.png to data/cifar-10/train/cat/47801.png
# Download 48285.png to data/cifar-10/train/cat/48285.png
# Download 48097.png to data/cifar-10/train/cat/48097.png
# Download 48040.png to data/cifar-10/train/cat/48040.png
# Download 48368.png to data/cifar-10/train/cat/48368.png
# Download 48170.png to data/cifar-10/train/cat/48170.png
# Download 48763.png to data/cifar-10/train/cat/48763.png
# Download 48599.png to data/cifar-10/train/cat/48599.png
# Download 48315.png to data/cifar-10/train/cat/48315.png
# Download 48572.png to data/cifar-10/train/cat/48572.png
# Download 48761.png to data/cifar-10/train/cat/48761.png
# Download 47973.png to data/cifar-10/train/cat/47973.png
# Download 48306.png to data/cifar-10/train/cat/48306.png
# Download 48132.png to data/cifar-10/train/cat/48132.png
# Download 48045.png to data/cifar-10/train/cat/48045.png
# Download 48326.png to data/cifar-10/train/cat/48326.png
# Download 47918.png to data/cifar-10/train/cat/47918.png
# Download 48657.png to data/cifar-10/train/cat/48657.png
# Download 47737.png to data/cifar-10/train/cat/47737.png
# Download 48976.png to data/cifar-10/train/cat/48976.png
# Download 47804.png to data/cifar-10/train/cat/47804.png
# Download 48585.png to data/cifar-10/train/cat/48585.png
# Download 48410.png to data/cifar-10/train/cat/48410.png
# Download 49015.png to data/cifar-10/train/cat/49015.png
# Download 48772.png to data/cifar-10/train/cat/48772.png
# Download 47892.png to data/cifar-10/train/cat/47892.png
# Download 46512.png to data/cifar-10/train/cat/46512.png
# Download 46496.png to data/cifar-10/train/cat/46496.png
# Download 46745.png to data/cifar-10/train/cat/46745.png
# Download 47502.png to data/cifar-10/train/cat/47502.png
# Download 47554.png to data/cifar-10/train/cat/47554.png
# Download 46594.png to data/cifar-10/train/cat/46594.png
# Download 46262.png to data/cifar-10/train/cat/46262.png
# Download 46232.png to data/cifar-10/train/cat/46232.png
# Download 47478.png to data/cifar-10/train/cat/47478.png
# Download 46425.png to data/cifar-10/train/cat/46425.png
# Download 46515.png to data/cifar-10/train/cat/46515.png
# Download 46295.png to data/cifar-10/train/cat/46295.png
# Download 46604.png to data/cifar-10/train/cat/46604.png
# Download 46919.png to data/cifar-10/train/cat/46919.png
# Download 46308.png to data/cifar-10/train/cat/46308.png
# Download 47219.png to data/cifar-10/train/cat/47219.png
# Download 47553.png to data/cifar-10/train/cat/47553.png
# Download 46349.png to data/cifar-10/train/cat/46349.png
# Download 47462.png to data/cifar-10/train/cat/47462.png
# Download 46555.png to data/cifar-10/train/cat/46555.png
# Download 47603.png to data/cifar-10/train/cat/47603.png
# Download 46682.png to data/cifar-10/train/cat/46682.png
# Download 46595.png to data/cifar-10/train/cat/46595.png
# Download 46729.png to data/cifar-10/train/cat/46729.png
# Download 47132.png to data/cifar-10/train/cat/47132.png
# Download 46198.png to data/cifar-10/train/cat/46198.png
# Download 46894.png to data/cifar-10/train/cat/46894.png
# Download 47547.png to data/cifar-10/train/cat/47547.png
# Download 46374.png to data/cifar-10/train/cat/46374.png
# Download 47327.png to data/cifar-10/train/cat/47327.png
# Download 47518.png to data/cifar-10/train/cat/47518.png
# Download 47413.png to data/cifar-10/train/cat/47413.png
# Download 46424.png to data/cifar-10/train/cat/46424.png
# Download 47198.png to data/cifar-10/train/cat/47198.png
# Download 47330.png to data/cifar-10/train/cat/47330.png
# Download 46204.png to data/cifar-10/train/cat/46204.png
# Download 47075.png to data/cifar-10/train/cat/47075.png
# Download 46799.png to data/cifar-10/train/cat/46799.png
# Download 46542.png to data/cifar-10/train/cat/46542.png
# Download 47306.png to data/cifar-10/train/cat/47306.png
# Download 46568.png to data/cifar-10/train/cat/46568.png
# Download 47494.png to data/cifar-10/train/cat/47494.png
# Download 47322.png to data/cifar-10/train/cat/47322.png
# Download 46596.png to data/cifar-10/train/cat/46596.png
# Download 46657.png to data/cifar-10/train/cat/46657.png
# Download 47044.png to data/cifar-10/train/cat/47044.png
# Download 47049.png to data/cifar-10/train/cat/47049.png
# Download 47666.png to data/cifar-10/train/cat/47666.png
# Download 46958.png to data/cifar-10/train/cat/46958.png
# Download 46432.png to data/cifar-10/train/cat/46432.png
# Download 46459.png to data/cifar-10/train/cat/46459.png
# Download 46423.png to data/cifar-10/train/cat/46423.png
# Download 46815.png to data/cifar-10/train/cat/46815.png
# Download 47439.png to data/cifar-10/train/cat/47439.png
# Download 46742.png to data/cifar-10/train/cat/46742.png
# Download 46653.png to data/cifar-10/train/cat/46653.png
# Download 47067.png to data/cifar-10/train/cat/47067.png
# Download 46411.png to data/cifar-10/train/cat/46411.png
# Download 46880.png to data/cifar-10/train/cat/46880.png
# Download 46399.png to data/cifar-10/train/cat/46399.png
# Download 46862.png to data/cifar-10/train/cat/46862.png
# Download 47204.png to data/cifar-10/train/cat/47204.png
# Download 47681.png to data/cifar-10/train/cat/47681.png
# Download 46437.png to data/cifar-10/train/cat/46437.png
# Download 46265.png to data/cifar-10/train/cat/46265.png
# Download 46841.png to data/cifar-10/train/cat/46841.png
# Download 47250.png to data/cifar-10/train/cat/47250.png
# Download 46341.png to data/cifar-10/train/cat/46341.png
# Download 46882.png to data/cifar-10/train/cat/46882.png
# Download 46337.png to data/cifar-10/train/cat/46337.png
# Download 46443.png to data/cifar-10/train/cat/46443.png
# Download 47138.png to data/cifar-10/train/cat/47138.png
# Download 46812.png to data/cifar-10/train/cat/46812.png
# Download 46757.png to data/cifar-10/train/cat/46757.png
# Download 47394.png to data/cifar-10/train/cat/47394.png
# Download 46688.png to data/cifar-10/train/cat/46688.png
# Download 46659.png to data/cifar-10/train/cat/46659.png
# Download 47526.png to data/cifar-10/train/cat/47526.png
# Download 46503.png to data/cifar-10/train/cat/46503.png
# Download 47722.png to data/cifar-10/train/cat/47722.png
# Download 46468.png to data/cifar-10/train/cat/46468.png
# Download 46196.png to data/cifar-10/train/cat/46196.png
# Download 46229.png to data/cifar-10/train/cat/46229.png
# Download 46697.png to data/cifar-10/train/cat/46697.png
# Download 46590.png to data/cifar-10/train/cat/46590.png
# Download 46500.png to data/cifar-10/train/cat/46500.png
# Download 46371.png to data/cifar-10/train/cat/46371.png
# Download 47100.png to data/cifar-10/train/cat/47100.png
# Download 47014.png to data/cifar-10/train/cat/47014.png
# Download 46838.png to data/cifar-10/train/cat/46838.png
# Download 46976.png to data/cifar-10/train/cat/46976.png
# Download 46493.png to data/cifar-10/train/cat/46493.png
# Download 46182.png to data/cifar-10/train/cat/46182.png
# Download 46886.png to data/cifar-10/train/cat/46886.png
# Download 47284.png to data/cifar-10/train/cat/47284.png
# Download 46352.png to data/cifar-10/train/cat/46352.png
# Download 46817.png to data/cifar-10/train/cat/46817.png
# Download 47721.png to data/cifar-10/train/cat/47721.png
# Download 47684.png to data/cifar-10/train/cat/47684.png
# Download 47683.png to data/cifar-10/train/cat/47683.png
# Download 47210.png to data/cifar-10/train/cat/47210.png
# Download 46962.png to data/cifar-10/train/cat/46962.png
# Download 47313.png to data/cifar-10/train/cat/47313.png
# Download 47643.png to data/cifar-10/train/cat/47643.png
# Download 46571.png to data/cifar-10/train/cat/46571.png
# Download 47490.png to data/cifar-10/train/cat/47490.png
# Download 46215.png to data/cifar-10/train/cat/46215.png
# Download 46605.png to data/cifar-10/train/cat/46605.png
# Download 47667.png to data/cifar-10/train/cat/47667.png
# Download 47146.png to data/cifar-10/train/cat/47146.png
# Download 47467.png to data/cifar-10/train/cat/47467.png
# Download 46354.png to data/cifar-10/train/cat/46354.png
# Download 47705.png to data/cifar-10/train/cat/47705.png
# Download 46347.png to data/cifar-10/train/cat/46347.png
# Download 46205.png to data/cifar-10/train/cat/46205.png
# Download 47717.png to data/cifar-10/train/cat/47717.png
# Download 47292.png to data/cifar-10/train/cat/47292.png
# Download 46712.png to data/cifar-10/train/cat/46712.png
# Download 47217.png to data/cifar-10/train/cat/47217.png
# Download 47098.png to data/cifar-10/train/cat/47098.png
# Download 46923.png to data/cifar-10/train/cat/46923.png
# Download 46466.png to data/cifar-10/train/cat/46466.png
# Download 46627.png to data/cifar-10/train/cat/46627.png
# Download 46805.png to data/cifar-10/train/cat/46805.png
# Download 46230.png to data/cifar-10/train/cat/46230.png
# Download 46414.png to data/cifar-10/train/cat/46414.png
# Download 47008.png to data/cifar-10/train/cat/47008.png
# Download 46932.png to data/cifar-10/train/cat/46932.png
# Download 46727.png to data/cifar-10/train/cat/46727.png
# Download 46825.png to data/cifar-10/train/cat/46825.png
# Download 46561.png to data/cifar-10/train/cat/46561.png
# Download 47541.png to data/cifar-10/train/cat/47541.png
# Download 47410.png to data/cifar-10/train/cat/47410.png
# Download 46286.png to data/cifar-10/train/cat/46286.png
# Download 47062.png to data/cifar-10/train/cat/47062.png
# Download 46855.png to data/cifar-10/train/cat/46855.png
# Download 46529.png to data/cifar-10/train/cat/46529.png
# Download 46472.png to data/cifar-10/train/cat/46472.png
# Download 47702.png to data/cifar-10/train/cat/47702.png
# Download 47196.png to data/cifar-10/train/cat/47196.png
# Download 47234.png to data/cifar-10/train/cat/47234.png
# Download 46801.png to data/cifar-10/train/cat/46801.png
# Download 47654.png to data/cifar-10/train/cat/47654.png
# Download 47539.png to data/cifar-10/train/cat/47539.png
# Download 46402.png to data/cifar-10/train/cat/46402.png
# Download 46939.png to data/cifar-10/train/cat/46939.png
# Download 46290.png to data/cifar-10/train/cat/46290.png
# Download 47475.png to data/cifar-10/train/cat/47475.png
# Download 46231.png to data/cifar-10/train/cat/46231.png
# Download 46977.png to data/cifar-10/train/cat/46977.png
# Download 46989.png to data/cifar-10/train/cat/46989.png
# Download 47131.png to data/cifar-10/train/cat/47131.png
# Download 46950.png to data/cifar-10/train/cat/46950.png
# Download 47523.png to data/cifar-10/train/cat/47523.png
# Download 46417.png to data/cifar-10/train/cat/46417.png
# Download 46433.png to data/cifar-10/train/cat/46433.png
# Download 47586.png to data/cifar-10/train/cat/47586.png
# Download 46226.png to data/cifar-10/train/cat/46226.png
# Download 46325.png to data/cifar-10/train/cat/46325.png
# Download 45590.png to data/cifar-10/train/cat/45590.png
# Download 46160.png to data/cifar-10/train/cat/46160.png
# Download 46094.png to data/cifar-10/train/cat/46094.png
# Download 46056.png to data/cifar-10/train/cat/46056.png
# Download 45931.png to data/cifar-10/train/cat/45931.png
# Download 44677.png to data/cifar-10/train/cat/44677.png
# Download 44855.png to data/cifar-10/train/cat/44855.png
# Download 45415.png to data/cifar-10/train/cat/45415.png
# Download 46070.png to data/cifar-10/train/cat/46070.png
# Download 44562.png to data/cifar-10/train/cat/44562.png
# Download 45885.png to data/cifar-10/train/cat/45885.png
# Download 45379.png to data/cifar-10/train/cat/45379.png
# Download 45251.png to data/cifar-10/train/cat/45251.png
# Download 44808.png to data/cifar-10/train/cat/44808.png
# Download 45456.png to data/cifar-10/train/cat/45456.png
# Download 45282.png to data/cifar-10/train/cat/45282.png
# Download 45066.png to data/cifar-10/train/cat/45066.png
# Download 44987.png to data/cifar-10/train/cat/44987.png
# Download 46081.png to data/cifar-10/train/cat/46081.png
# Download 45568.png to data/cifar-10/train/cat/45568.png
# Download 45310.png to data/cifar-10/train/cat/45310.png
# Download 45854.png to data/cifar-10/train/cat/45854.png
# Download 45948.png to data/cifar-10/train/cat/45948.png
# Download 44897.png to data/cifar-10/train/cat/44897.png
# Download 44707.png to data/cifar-10/train/cat/44707.png
# Download 45117.png to data/cifar-10/train/cat/45117.png
# Download 44745.png to data/cifar-10/train/cat/44745.png
# Download 45502.png to data/cifar-10/train/cat/45502.png
# Download 45631.png to data/cifar-10/train/cat/45631.png
# Download 45752.png to data/cifar-10/train/cat/45752.png
# Download 45402.png to data/cifar-10/train/cat/45402.png
# Download 45209.png to data/cifar-10/train/cat/45209.png
# Download 44859.png to data/cifar-10/train/cat/44859.png
# Download 44636.png to data/cifar-10/train/cat/44636.png
# Download 44913.png to data/cifar-10/train/cat/44913.png
# Download 45909.png to data/cifar-10/train/cat/45909.png
# Download 44543.png to data/cifar-10/train/cat/44543.png
# Download 44585.png to data/cifar-10/train/cat/44585.png
# Download 45514.png to data/cifar-10/train/cat/45514.png
# Download 44926.png to data/cifar-10/train/cat/44926.png
# Download 45091.png to data/cifar-10/train/cat/45091.png
# Download 45319.png to data/cifar-10/train/cat/45319.png
# Download 44852.png to data/cifar-10/train/cat/44852.png
# Download 45908.png to data/cifar-10/train/cat/45908.png
# Download 45479.png to data/cifar-10/train/cat/45479.png
# Download 45249.png to data/cifar-10/train/cat/45249.png
# Download 44980.png to data/cifar-10/train/cat/44980.png
# Download 46080.png to data/cifar-10/train/cat/46080.png
# Download 44631.png to data/cifar-10/train/cat/44631.png
# Download 45053.png to data/cifar-10/train/cat/45053.png
# Download 45933.png to data/cifar-10/train/cat/45933.png
# Download 44943.png to data/cifar-10/train/cat/44943.png
# Download 45250.png to data/cifar-10/train/cat/45250.png
# Download 45082.png to data/cifar-10/train/cat/45082.png
# Download 44898.png to data/cifar-10/train/cat/44898.png
# Download 45151.png to data/cifar-10/train/cat/45151.png
# Download 45158.png to data/cifar-10/train/cat/45158.png
# Download 45351.png to data/cifar-10/train/cat/45351.png
# Download 45433.png to data/cifar-10/train/cat/45433.png
# Download 45467.png to data/cifar-10/train/cat/45467.png
# Download 45625.png to data/cifar-10/train/cat/45625.png
# Download 44704.png to data/cifar-10/train/cat/44704.png
# Download 46149.png to data/cifar-10/train/cat/46149.png
# Download 44957.png to data/cifar-10/train/cat/44957.png
# Download 45667.png to data/cifar-10/train/cat/45667.png
# Download 44865.png to data/cifar-10/train/cat/44865.png
# Download 45711.png to data/cifar-10/train/cat/45711.png
# Download 46037.png to data/cifar-10/train/cat/46037.png
# Download 45700.png to data/cifar-10/train/cat/45700.png
# Download 44628.png to data/cifar-10/train/cat/44628.png
# Download 45191.png to data/cifar-10/train/cat/45191.png
# Download 45128.png to data/cifar-10/train/cat/45128.png
# Download 46136.png to data/cifar-10/train/cat/46136.png
# Download 44950.png to data/cifar-10/train/cat/44950.png
# Download 46155.png to data/cifar-10/train/cat/46155.png
# Download 44635.png to data/cifar-10/train/cat/44635.png
# Download 44893.png to data/cifar-10/train/cat/44893.png
# Download 46058.png to data/cifar-10/train/cat/46058.png
# Download 46121.png to data/cifar-10/train/cat/46121.png
# Download 45691.png to data/cifar-10/train/cat/45691.png
# Download 46157.png to data/cifar-10/train/cat/46157.png
# Download 44973.png to data/cifar-10/train/cat/44973.png
# Download 45816.png to data/cifar-10/train/cat/45816.png
# Download 46110.png to data/cifar-10/train/cat/46110.png
# Download 45330.png to data/cifar-10/train/cat/45330.png
# Download 45137.png to data/cifar-10/train/cat/45137.png
# Download 45670.png to data/cifar-10/train/cat/45670.png
# Download 45757.png to data/cifar-10/train/cat/45757.png
# Download 45508.png to data/cifar-10/train/cat/45508.png
# Download 45789.png to data/cifar-10/train/cat/45789.png
# Download 44976.png to data/cifar-10/train/cat/44976.png
# Download 44819.png to data/cifar-10/train/cat/44819.png
# Download 46109.png to data/cifar-10/train/cat/46109.png
# Download 44800.png to data/cifar-10/train/cat/44800.png
# Download 46013.png to data/cifar-10/train/cat/46013.png
# Download 45075.png to data/cifar-10/train/cat/45075.png
# Download 46141.png to data/cifar-10/train/cat/46141.png
# Download 45380.png to data/cifar-10/train/cat/45380.png
# Download 45897.png to data/cifar-10/train/cat/45897.png
# Download 45634.png to data/cifar-10/train/cat/45634.png
# Download 44896.png to data/cifar-10/train/cat/44896.png
# Download 44673.png to data/cifar-10/train/cat/44673.png
# Download 45857.png to data/cifar-10/train/cat/45857.png
# Download 45850.png to data/cifar-10/train/cat/45850.png
# Download 44621.png to data/cifar-10/train/cat/44621.png
# Download 45382.png to data/cifar-10/train/cat/45382.png
# Download 46085.png to data/cifar-10/train/cat/46085.png
# Download 44868.png to data/cifar-10/train/cat/44868.png
# Download 44768.png to data/cifar-10/train/cat/44768.png
# Download 44530.png to data/cifar-10/train/cat/44530.png
# Download 44657.png to data/cifar-10/train/cat/44657.png
# Download 45217.png to data/cifar-10/train/cat/45217.png
# Download 45389.png to data/cifar-10/train/cat/45389.png
# Download 45641.png to data/cifar-10/train/cat/45641.png
# Download 45152.png to data/cifar-10/train/cat/45152.png
# Download 45012.png to data/cifar-10/train/cat/45012.png
# Download 44802.png to data/cifar-10/train/cat/44802.png
# Download 45175.png to data/cifar-10/train/cat/45175.png
# Download 44856.png to data/cifar-10/train/cat/44856.png
# Download 45395.png to data/cifar-10/train/cat/45395.png
# Download 45458.png to data/cifar-10/train/cat/45458.png
# Download 45454.png to data/cifar-10/train/cat/45454.png
# Download 46023.png to data/cifar-10/train/cat/46023.png
# Download 45038.png to data/cifar-10/train/cat/45038.png
# Download 45275.png to data/cifar-10/train/cat/45275.png
# Download 45949.png to data/cifar-10/train/cat/45949.png
# Download 45914.png to data/cifar-10/train/cat/45914.png
# Download 45928.png to data/cifar-10/train/cat/45928.png
# Download 45026.png to data/cifar-10/train/cat/45026.png
# Download 45783.png to data/cifar-10/train/cat/45783.png
# Download 45921.png to data/cifar-10/train/cat/45921.png
# Download 45754.png to data/cifar-10/train/cat/45754.png
# Download 44663.png to data/cifar-10/train/cat/44663.png
# Download 44953.png to data/cifar-10/train/cat/44953.png
# Download 45192.png to data/cifar-10/train/cat/45192.png
# Download 45471.png to data/cifar-10/train/cat/45471.png
# Download 46002.png to data/cifar-10/train/cat/46002.png
# Download 45439.png to data/cifar-10/train/cat/45439.png
# Download 45362.png to data/cifar-10/train/cat/45362.png
# Download 45216.png to data/cifar-10/train/cat/45216.png
# Download 45901.png to data/cifar-10/train/cat/45901.png
# Download 44576.png to data/cifar-10/train/cat/44576.png
# Download 45947.png to data/cifar-10/train/cat/45947.png
# Download 45896.png to data/cifar-10/train/cat/45896.png
# Download 45732.png to data/cifar-10/train/cat/45732.png
# Download 45542.png to data/cifar-10/train/cat/45542.png
# Download 45632.png to data/cifar-10/train/cat/45632.png
# Download 44693.png to data/cifar-10/train/cat/44693.png
# Download 45057.png to data/cifar-10/train/cat/45057.png
# Download 46062.png to data/cifar-10/train/cat/46062.png
# Download 45778.png to data/cifar-10/train/cat/45778.png
# Download 45661.png to data/cifar-10/train/cat/45661.png
# Download 44550.png to data/cifar-10/train/cat/44550.png
# Download 45646.png to data/cifar-10/train/cat/45646.png
# Download 45236.png to data/cifar-10/train/cat/45236.png
# Download 45211.png to data/cifar-10/train/cat/45211.png
# Download 44944.png to data/cifar-10/train/cat/44944.png
# Download 45552.png to data/cifar-10/train/cat/45552.png
# Download 43072.png to data/cifar-10/train/cat/43072.png
# Download 44263.png to data/cifar-10/train/cat/44263.png
# Download 43551.png to data/cifar-10/train/cat/43551.png
# Download 44127.png to data/cifar-10/train/cat/44127.png
# Download 43126.png to data/cifar-10/train/cat/43126.png
# Download 42999.png to data/cifar-10/train/cat/42999.png
# Download 43034.png to data/cifar-10/train/cat/43034.png
# Download 44047.png to data/cifar-10/train/cat/44047.png
# Download 43052.png to data/cifar-10/train/cat/43052.png
# Download 43701.png to data/cifar-10/train/cat/43701.png
# Download 43204.png to data/cifar-10/train/cat/43204.png
# Download 43726.png to data/cifar-10/train/cat/43726.png
# Download 43752.png to data/cifar-10/train/cat/43752.png
# Download 43685.png to data/cifar-10/train/cat/43685.png
# Download 44142.png to data/cifar-10/train/cat/44142.png
# Download 43598.png to data/cifar-10/train/cat/43598.png
# Download 43385.png to data/cifar-10/train/cat/43385.png
# Download 44192.png to data/cifar-10/train/cat/44192.png
# Download 44313.png to data/cifar-10/train/cat/44313.png
# Download 44399.png to data/cifar-10/train/cat/44399.png
# Download 43981.png to data/cifar-10/train/cat/43981.png
# Download 43402.png to data/cifar-10/train/cat/43402.png
# Download 43779.png to data/cifar-10/train/cat/43779.png
# Download 43968.png to data/cifar-10/train/cat/43968.png
# Download 44197.png to data/cifar-10/train/cat/44197.png
# Download 43336.png to data/cifar-10/train/cat/43336.png
# Download 44219.png to data/cifar-10/train/cat/44219.png
# Download 43500.png to data/cifar-10/train/cat/43500.png
# Download 44355.png to data/cifar-10/train/cat/44355.png
# Download 42970.png to data/cifar-10/train/cat/42970.png
# Download 44232.png to data/cifar-10/train/cat/44232.png
# Download 43704.png to data/cifar-10/train/cat/43704.png
# Download 43283.png to data/cifar-10/train/cat/43283.png
# Download 43440.png to data/cifar-10/train/cat/43440.png
# Download 44144.png to data/cifar-10/train/cat/44144.png
# Download 43123.png to data/cifar-10/train/cat/43123.png
# Download 43243.png to data/cifar-10/train/cat/43243.png
# Download 43438.png to data/cifar-10/train/cat/43438.png
# Download 43464.png to data/cifar-10/train/cat/43464.png
# Download 44139.png to data/cifar-10/train/cat/44139.png
# Download 43262.png to data/cifar-10/train/cat/43262.png
# Download 44507.png to data/cifar-10/train/cat/44507.png
# Download 42953.png to data/cifar-10/train/cat/42953.png
# Download 43349.png to data/cifar-10/train/cat/43349.png
# Download 43720.png to data/cifar-10/train/cat/43720.png
# Download 43690.png to data/cifar-10/train/cat/43690.png
# Download 44451.png to data/cifar-10/train/cat/44451.png
# Download 44110.png to data/cifar-10/train/cat/44110.png
# Download 44084.png to data/cifar-10/train/cat/44084.png
# Download 43040.png to data/cifar-10/train/cat/43040.png
# Download 43562.png to data/cifar-10/train/cat/43562.png
# Download 44267.png to data/cifar-10/train/cat/44267.png
# Download 43877.png to data/cifar-10/train/cat/43877.png
# Download 43313.png to data/cifar-10/train/cat/43313.png
# Download 43257.png to data/cifar-10/train/cat/43257.png
# Download 43971.png to data/cifar-10/train/cat/43971.png
# Download 43428.png to data/cifar-10/train/cat/43428.png
# Download 44419.png to data/cifar-10/train/cat/44419.png
# Download 43462.png to data/cifar-10/train/cat/43462.png
# Download 43813.png to data/cifar-10/train/cat/43813.png
# Download 43630.png to data/cifar-10/train/cat/43630.png
# Download 44152.png to data/cifar-10/train/cat/44152.png
# Download 43187.png to data/cifar-10/train/cat/43187.png
# Download 42997.png to data/cifar-10/train/cat/42997.png
# Download 43850.png to data/cifar-10/train/cat/43850.png
# Download 44318.png to data/cifar-10/train/cat/44318.png
# Download 43043.png to data/cifar-10/train/cat/43043.png
# Download 43254.png to data/cifar-10/train/cat/43254.png
# Download 44481.png to data/cifar-10/train/cat/44481.png
# Download 44173.png to data/cifar-10/train/cat/44173.png
# Download 44020.png to data/cifar-10/train/cat/44020.png
# Download 44191.png to data/cifar-10/train/cat/44191.png
# Download 43328.png to data/cifar-10/train/cat/43328.png
# Download 43784.png to data/cifar-10/train/cat/43784.png
# Download 43110.png to data/cifar-10/train/cat/43110.png
# Download 44390.png to data/cifar-10/train/cat/44390.png
# Download 44233.png to data/cifar-10/train/cat/44233.png
# Download 44455.png to data/cifar-10/train/cat/44455.png
# Download 43836.png to data/cifar-10/train/cat/43836.png
# Download 43576.png to data/cifar-10/train/cat/43576.png
# Download 43707.png to data/cifar-10/train/cat/43707.png
# Download 44120.png to data/cifar-10/train/cat/44120.png
# Download 43565.png to data/cifar-10/train/cat/43565.png
# Download 43843.png to data/cifar-10/train/cat/43843.png
# Download 43845.png to data/cifar-10/train/cat/43845.png
# Download 43773.png to data/cifar-10/train/cat/43773.png
# Download 43751.png to data/cifar-10/train/cat/43751.png
# Download 44383.png to data/cifar-10/train/cat/44383.png
# Download 43626.png to data/cifar-10/train/cat/43626.png
# Download 43490.png to data/cifar-10/train/cat/43490.png
# Download 43013.png to data/cifar-10/train/cat/43013.png
# Download 44276.png to data/cifar-10/train/cat/44276.png
# Download 43018.png to data/cifar-10/train/cat/43018.png
# Download 43237.png to data/cifar-10/train/cat/43237.png
# Download 43841.png to data/cifar-10/train/cat/43841.png
# Download 43799.png to data/cifar-10/train/cat/43799.png
# Download 43742.png to data/cifar-10/train/cat/43742.png
# Download 43065.png to data/cifar-10/train/cat/43065.png
# Download 43812.png to data/cifar-10/train/cat/43812.png
# Download 44093.png to data/cifar-10/train/cat/44093.png
# Download 44103.png to data/cifar-10/train/cat/44103.png
# Download 43633.png to data/cifar-10/train/cat/43633.png
# Download 43295.png to data/cifar-10/train/cat/43295.png
# Download 44513.png to data/cifar-10/train/cat/44513.png
# Download 43084.png to data/cifar-10/train/cat/43084.png
# Download 44354.png to data/cifar-10/train/cat/44354.png
# Download 43411.png to data/cifar-10/train/cat/43411.png
# Download 43497.png to data/cifar-10/train/cat/43497.png
# Download 43827.png to data/cifar-10/train/cat/43827.png
# Download 42949.png to data/cifar-10/train/cat/42949.png
# Download 43487.png to data/cifar-10/train/cat/43487.png
# Download 43922.png to data/cifar-10/train/cat/43922.png
# Download 43733.png to data/cifar-10/train/cat/43733.png
# Download 44323.png to data/cifar-10/train/cat/44323.png
# Download 43722.png to data/cifar-10/train/cat/43722.png
# Download 43554.png to data/cifar-10/train/cat/43554.png
# Download 44381.png to data/cifar-10/train/cat/44381.png
# Download 43493.png to data/cifar-10/train/cat/43493.png
# Download 43105.png to data/cifar-10/train/cat/43105.png
# Download 43737.png to data/cifar-10/train/cat/43737.png
# Download 44039.png to data/cifar-10/train/cat/44039.png
# Download 43730.png to data/cifar-10/train/cat/43730.png
# Download 44029.png to data/cifar-10/train/cat/44029.png
# Download 43767.png to data/cifar-10/train/cat/43767.png
# Download 44409.png to data/cifar-10/train/cat/44409.png
# Download 44429.png to data/cifar-10/train/cat/44429.png
# Download 43352.png to data/cifar-10/train/cat/43352.png
# Download 43744.png to data/cifar-10/train/cat/43744.png
# Download 44252.png to data/cifar-10/train/cat/44252.png
# Download 43749.png to data/cifar-10/train/cat/43749.png
# Download 43978.png to data/cifar-10/train/cat/43978.png
# Download 43339.png to data/cifar-10/train/cat/43339.png
# Download 44124.png to data/cifar-10/train/cat/44124.png
# Download 43832.png to data/cifar-10/train/cat/43832.png
# Download 43776.png to data/cifar-10/train/cat/43776.png
# Download 43318.png to data/cifar-10/train/cat/43318.png
# Download 44234.png to data/cifar-10/train/cat/44234.png
# Download 43953.png to data/cifar-10/train/cat/43953.png
# Download 44153.png to data/cifar-10/train/cat/44153.png
# Download 43716.png to data/cifar-10/train/cat/43716.png
# Download 44226.png to data/cifar-10/train/cat/44226.png
# Download 44322.png to data/cifar-10/train/cat/44322.png
# Download 43472.png to data/cifar-10/train/cat/43472.png
# Download 43533.png to data/cifar-10/train/cat/43533.png
# Download 43800.png to data/cifar-10/train/cat/43800.png
# Download 44456.png to data/cifar-10/train/cat/44456.png
# Download 44408.png to data/cifar-10/train/cat/44408.png
# Download 43955.png to data/cifar-10/train/cat/43955.png
# Download 43735.png to data/cifar-10/train/cat/43735.png
# Download 43606.png to data/cifar-10/train/cat/43606.png
# Download 44108.png to data/cifar-10/train/cat/44108.png
# Download 43762.png to data/cifar-10/train/cat/43762.png
# Download 44376.png to data/cifar-10/train/cat/44376.png
# Download 43456.png to data/cifar-10/train/cat/43456.png
# Download 43233.png to data/cifar-10/train/cat/43233.png
# Download 43573.png to data/cifar-10/train/cat/43573.png
# Download 43017.png to data/cifar-10/train/cat/43017.png
# Download 43382.png to data/cifar-10/train/cat/43382.png
# Download 43430.png to data/cifar-10/train/cat/43430.png
# Download 41349.png to data/cifar-10/train/cat/41349.png
# Download 42740.png to data/cifar-10/train/cat/42740.png
# Download 42365.png to data/cifar-10/train/cat/42365.png
# Download 42021.png to data/cifar-10/train/cat/42021.png
# Download 42522.png to data/cifar-10/train/cat/42522.png
# Download 41478.png to data/cifar-10/train/cat/41478.png
# Download 42914.png to data/cifar-10/train/cat/42914.png
# Download 42496.png to data/cifar-10/train/cat/42496.png
# Download 41989.png to data/cifar-10/train/cat/41989.png
# Download 41364.png to data/cifar-10/train/cat/41364.png
# Download 41738.png to data/cifar-10/train/cat/41738.png
# Download 41713.png to data/cifar-10/train/cat/41713.png
# Download 42604.png to data/cifar-10/train/cat/42604.png
# Download 42806.png to data/cifar-10/train/cat/42806.png
# Download 42195.png to data/cifar-10/train/cat/42195.png
# Download 42433.png to data/cifar-10/train/cat/42433.png
# Download 42744.png to data/cifar-10/train/cat/42744.png
# Download 41581.png to data/cifar-10/train/cat/41581.png
# Download 42189.png to data/cifar-10/train/cat/42189.png
# Download 41323.png to data/cifar-10/train/cat/41323.png
# Download 42336.png to data/cifar-10/train/cat/42336.png
# Download 42122.png to data/cifar-10/train/cat/42122.png
# Download 42206.png to data/cifar-10/train/cat/42206.png
# Download 41998.png to data/cifar-10/train/cat/41998.png
# Download 42670.png to data/cifar-10/train/cat/42670.png
# Download 41394.png to data/cifar-10/train/cat/41394.png
# Download 42056.png to data/cifar-10/train/cat/42056.png
# Download 42192.png to data/cifar-10/train/cat/42192.png
# Download 42357.png to data/cifar-10/train/cat/42357.png
# Download 41715.png to data/cifar-10/train/cat/41715.png
# Download 41866.png to data/cifar-10/train/cat/41866.png
# Download 41952.png to data/cifar-10/train/cat/41952.png
# Download 42752.png to data/cifar-10/train/cat/42752.png
# Download 41497.png to data/cifar-10/train/cat/41497.png
# Download 42084.png to data/cifar-10/train/cat/42084.png
# Download 41334.png to data/cifar-10/train/cat/41334.png
# Download 41545.png to data/cifar-10/train/cat/41545.png
# Download 42647.png to data/cifar-10/train/cat/42647.png
# Download 41694.png to data/cifar-10/train/cat/41694.png
# Download 41369.png to data/cifar-10/train/cat/41369.png
# Download 41845.png to data/cifar-10/train/cat/41845.png
# Download 42223.png to data/cifar-10/train/cat/42223.png
# Download 42736.png to data/cifar-10/train/cat/42736.png
# Download 41872.png to data/cifar-10/train/cat/41872.png
# Download 42801.png to data/cifar-10/train/cat/42801.png
# Download 42558.png to data/cifar-10/train/cat/42558.png
# Download 42417.png to data/cifar-10/train/cat/42417.png
# Download 41428.png to data/cifar-10/train/cat/41428.png
# Download 42853.png to data/cifar-10/train/cat/42853.png
# Download 41874.png to data/cifar-10/train/cat/41874.png
# Download 41589.png to data/cifar-10/train/cat/41589.png
# Download 42501.png to data/cifar-10/train/cat/42501.png
# Download 41827.png to data/cifar-10/train/cat/41827.png
# Download 42757.png to data/cifar-10/train/cat/42757.png
# Download 41446.png to data/cifar-10/train/cat/41446.png
# Download 41343.png to data/cifar-10/train/cat/41343.png
# Download 41601.png to data/cifar-10/train/cat/41601.png
# Download 42880.png to data/cifar-10/train/cat/42880.png
# Download 41734.png to data/cifar-10/train/cat/41734.png
# Download 42548.png to data/cifar-10/train/cat/42548.png
# Download 41306.png to data/cifar-10/train/cat/41306.png
# Download 42738.png to data/cifar-10/train/cat/42738.png
# Download 42920.png to data/cifar-10/train/cat/42920.png
# Download 41412.png to data/cifar-10/train/cat/41412.png
# Download 42827.png to data/cifar-10/train/cat/42827.png
# Download 42131.png to data/cifar-10/train/cat/42131.png
# Download 42547.png to data/cifar-10/train/cat/42547.png
# Download 41918.png to data/cifar-10/train/cat/41918.png
# Download 41353.png to data/cifar-10/train/cat/41353.png
# Download 41853.png to data/cifar-10/train/cat/41853.png
# Download 42012.png to data/cifar-10/train/cat/42012.png
# Download 42037.png to data/cifar-10/train/cat/42037.png
# Download 42233.png to data/cifar-10/train/cat/42233.png
# Download 42011.png to data/cifar-10/train/cat/42011.png
# Download 41673.png to data/cifar-10/train/cat/41673.png
# Download 42825.png to data/cifar-10/train/cat/42825.png
# Download 41914.png to data/cifar-10/train/cat/41914.png
# Download 42930.png to data/cifar-10/train/cat/42930.png
# Download 42482.png to data/cifar-10/train/cat/42482.png
# Download 41782.png to data/cifar-10/train/cat/41782.png
# Download 41903.png to data/cifar-10/train/cat/41903.png
# Download 41597.png to data/cifar-10/train/cat/41597.png
# Download 41540.png to data/cifar-10/train/cat/41540.png
# Download 41658.png to data/cifar-10/train/cat/41658.png
# Download 42845.png to data/cifar-10/train/cat/42845.png
# Download 42252.png to data/cifar-10/train/cat/42252.png
# Download 42028.png to data/cifar-10/train/cat/42028.png
# Download 41871.png to data/cifar-10/train/cat/41871.png
# Download 42474.png to data/cifar-10/train/cat/42474.png
# Download 41951.png to data/cifar-10/train/cat/41951.png
# Download 42508.png to data/cifar-10/train/cat/42508.png
# Download 41514.png to data/cifar-10/train/cat/41514.png
# Download 41493.png to data/cifar-10/train/cat/41493.png
# Download 42354.png to data/cifar-10/train/cat/42354.png
# Download 41389.png to data/cifar-10/train/cat/41389.png
# Download 42411.png to data/cifar-10/train/cat/42411.png
# Download 41461.png to data/cifar-10/train/cat/41461.png
# Download 41513.png to data/cifar-10/train/cat/41513.png
# Download 42481.png to data/cifar-10/train/cat/42481.png
# Download 41269.png to data/cifar-10/train/cat/41269.png
# Download 42258.png to data/cifar-10/train/cat/42258.png
# Download 42737.png to data/cifar-10/train/cat/42737.png
# Download 42351.png to data/cifar-10/train/cat/42351.png
# Download 42650.png to data/cifar-10/train/cat/42650.png
# Download 42153.png to data/cifar-10/train/cat/42153.png
# Download 41594.png to data/cifar-10/train/cat/41594.png
# Download 42455.png to data/cifar-10/train/cat/42455.png
# Download 42800.png to data/cifar-10/train/cat/42800.png
# Download 42783.png to data/cifar-10/train/cat/42783.png
# Download 41945.png to data/cifar-10/train/cat/41945.png
# Download 41826.png to data/cifar-10/train/cat/41826.png
# Download 41578.png to data/cifar-10/train/cat/41578.png
# Download 41937.png to data/cifar-10/train/cat/41937.png
# Download 41511.png to data/cifar-10/train/cat/41511.png
# Download 42321.png to data/cifar-10/train/cat/42321.png
# Download 42370.png to data/cifar-10/train/cat/42370.png
# Download 42479.png to data/cifar-10/train/cat/42479.png
# Download 42865.png to data/cifar-10/train/cat/42865.png
# Download 41285.png to data/cifar-10/train/cat/41285.png
# Download 41992.png to data/cifar-10/train/cat/41992.png
# Download 42766.png to data/cifar-10/train/cat/42766.png
# Download 41944.png to data/cifar-10/train/cat/41944.png
# Download 42382.png to data/cifar-10/train/cat/42382.png
# Download 41384.png to data/cifar-10/train/cat/41384.png
# Download 42837.png to data/cifar-10/train/cat/42837.png
# Download 42657.png to data/cifar-10/train/cat/42657.png
# Download 42074.png to data/cifar-10/train/cat/42074.png
# Download 41372.png to data/cifar-10/train/cat/41372.png
# Download 42445.png to data/cifar-10/train/cat/42445.png
# Download 41421.png to data/cifar-10/train/cat/41421.png
# Download 42590.png to data/cifar-10/train/cat/42590.png
# Download 41569.png to data/cifar-10/train/cat/41569.png
# Download 42023.png to data/cifar-10/train/cat/42023.png
# ...
# Download 12033.png to data/cifar-10/train/cat/12033.png
# Download 11596.png to data/cifar-10/train/cat/11596.png
# Download 12113.png to data/cifar-10/train/cat/12113.png
# Download 11623.png to data/cifar-10/train/cat/11623.png
# Download 11568.png to data/cifar-10/train/cat/11568.png
# Download 11758.png to data/cifar-10/train/cat/11758.png
# Download 12050.png to data/cifar-10/train/cat/12050.png
# Download 12965.png to data/cifar-10/train/cat/12965.png
# Download 13061.png to data/cifar-10/train/cat/13061.png
# Download 11894.png to data/cifar-10/train/cat/11894.png
# Download 12440.png to data/cifar-10/train/cat/12440.png
# Download 12811.png to data/cifar-10/train/cat/12811.png
# Download 12045.png to data/cifar-10/train/cat/12045.png
# Download 11434.png to data/cifar-10/train/cat/11434.png
# Download 12969.png to data/cifar-10/train/cat/12969.png
# Download 11960.png to data/cifar-10/train/cat/11960.png
# Download 12190.png to data/cifar-10/train/cat/12190.png
# Download 11724.png to data/cifar-10/train/cat/11724.png
# Download 12631.png to data/cifar-10/train/cat/12631.png
# Download 11763.png to data/cifar-10/train/cat/11763.png
# Download 12377.png to data/cifar-10/train/cat/12377.png
# Download 12647.png to data/cifar-10/train/cat/12647.png
# Download 13062.png to data/cifar-10/train/cat/13062.png
# Download 13019.png to data/cifar-10/train/cat/13019.png
# Download 11929.png to data/cifar-10/train/cat/11929.png
# Download 12225.png to data/cifar-10/train/cat/12225.png
# Download 11809.png to data/cifar-10/train/cat/11809.png
# Download 12454.png to data/cifar-10/train/cat/12454.png
# Download 12211.png to data/cifar-10/train/cat/12211.png
# Download 12671.png to data/cifar-10/train/cat/12671.png
# Download 13064.png to data/cifar-10/train/cat/13064.png
# Download 11655.png to data/cifar-10/train/cat/11655.png
# Download 11752.png to data/cifar-10/train/cat/11752.png
# Download 12278.png to data/cifar-10/train/cat/12278.png
# Download 12681.png to data/cifar-10/train/cat/12681.png
# Download 12391.png to data/cifar-10/train/cat/12391.png
# Download 11447.png to data/cifar-10/train/cat/11447.png
# Download 12500.png to data/cifar-10/train/cat/12500.png
# Download 12882.png to data/cifar-10/train/cat/12882.png
# Download 12853.png to data/cifar-10/train/cat/12853.png
# Download 12707.png to data/cifar-10/train/cat/12707.png
# Download 12032.png to data/cifar-10/train/cat/12032.png
# Download 11970.png to data/cifar-10/train/cat/11970.png
# Download 11718.png to data/cifar-10/train/cat/11718.png
# Download 11632.png to data/cifar-10/train/cat/11632.png
# Download 12147.png to data/cifar-10/train/cat/12147.png
# Download 11540.png to data/cifar-10/train/cat/11540.png
# Download 11653.png to data/cifar-10/train/cat/11653.png
# Download 12105.png to data/cifar-10/train/cat/12105.png
# Download 12332.png to data/cifar-10/train/cat/12332.png
# Download 12342.png to data/cifar-10/train/cat/12342.png
# Download 11498.png to data/cifar-10/train/cat/11498.png
# Download 13093.png to data/cifar-10/train/cat/13093.png
# Download 11476.png to data/cifar-10/train/cat/11476.png
# Download 12436.png to data/cifar-10/train/cat/12436.png
# Download 12370.png to data/cifar-10/train/cat/12370.png
# Download 12195.png to data/cifar-10/train/cat/12195.png
# Download 13001.png to data/cifar-10/train/cat/13001.png
# Download 12870.png to data/cifar-10/train/cat/12870.png
# Download 12316.png to data/cifar-10/train/cat/12316.png
# Download 10557.png to data/cifar-10/train/cat/10557.png
# Download 11199.png to data/cifar-10/train/cat/11199.png
# Download 9973.png to data/cifar-10/train/cat/9973.png
# Download 9792.png to data/cifar-10/train/cat/9792.png
# Download 10854.png to data/cifar-10/train/cat/10854.png
# Download 10931.png to data/cifar-10/train/cat/10931.png
# Download 10439.png to data/cifar-10/train/cat/10439.png
# Download 11294.png to data/cifar-10/train/cat/11294.png
# Download 9892.png to data/cifar-10/train/cat/9892.png
# Download 9794.png to data/cifar-10/train/cat/9794.png
# Download 10999.png to data/cifar-10/train/cat/10999.png
# Download 9943.png to data/cifar-10/train/cat/9943.png
# Download 10048.png to data/cifar-10/train/cat/10048.png
# Download 9908.png to data/cifar-10/train/cat/9908.png
# Download 11211.png to data/cifar-10/train/cat/11211.png
# Download 10937.png to data/cifar-10/train/cat/10937.png
# Download 10843.png to data/cifar-10/train/cat/10843.png
# Download 11386.png to data/cifar-10/train/cat/11386.png
# Download 10918.png to data/cifar-10/train/cat/10918.png
# Download 10193.png to data/cifar-10/train/cat/10193.png
# Download 10746.png to data/cifar-10/train/cat/10746.png
# Download 10463.png to data/cifar-10/train/cat/10463.png
# Download 10634.png to data/cifar-10/train/cat/10634.png
# Download 10209.png to data/cifar-10/train/cat/10209.png
# Download 10784.png to data/cifar-10/train/cat/10784.png
# Download 11419.png to data/cifar-10/train/cat/11419.png
# Download 10454.png to data/cifar-10/train/cat/10454.png
# Download 10575.png to data/cifar-10/train/cat/10575.png
# Download 10254.png to data/cifar-10/train/cat/10254.png
# Download 10958.png to data/cifar-10/train/cat/10958.png
# Download 10186.png to data/cifar-10/train/cat/10186.png
# Download 10948.png to data/cifar-10/train/cat/10948.png
# Download 10587.png to data/cifar-10/train/cat/10587.png
# Download 11131.png to data/cifar-10/train/cat/11131.png
# Download 9927.png to data/cifar-10/train/cat/9927.png
# Download 11357.png to data/cifar-10/train/cat/11357.png
# Download 11026.png to data/cifar-10/train/cat/11026.png
# Download 10125.png to data/cifar-10/train/cat/10125.png
# Download 9738.png to data/cifar-10/train/cat/9738.png
# Download 10321.png to data/cifar-10/train/cat/10321.png
# Download 10255.png to data/cifar-10/train/cat/10255.png
# Download 10508.png to data/cifar-10/train/cat/10508.png
# Download 10427.png to data/cifar-10/train/cat/10427.png
# Download 10101.png to data/cifar-10/train/cat/10101.png
# Download 9846.png to data/cifar-10/train/cat/9846.png
# Download 10558.png to data/cifar-10/train/cat/10558.png
# Download 10534.png to data/cifar-10/train/cat/10534.png
# Download 10705.png to data/cifar-10/train/cat/10705.png
# Download 10942.png to data/cifar-10/train/cat/10942.png
# Download 10383.png to data/cifar-10/train/cat/10383.png
# Download 10929.png to data/cifar-10/train/cat/10929.png
# Download 10304.png to data/cifar-10/train/cat/10304.png
# Download 9976.png to data/cifar-10/train/cat/9976.png
# Download 11271.png to data/cifar-10/train/cat/11271.png
# Download 10070.png to data/cifar-10/train/cat/10070.png
# Download 10618.png to data/cifar-10/train/cat/10618.png
# Download 11366.png to data/cifar-10/train/cat/11366.png
# Download 10005.png to data/cifar-10/train/cat/10005.png
# Download 9720.png to data/cifar-10/train/cat/9720.png
# Download 10085.png to data/cifar-10/train/cat/10085.png
# Download 9830.png to data/cifar-10/train/cat/9830.png
# Download 10749.png to data/cifar-10/train/cat/10749.png
# Download 11025.png to data/cifar-10/train/cat/11025.png
# Download 11222.png to data/cifar-10/train/cat/11222.png
# Download 9841.png to data/cifar-10/train/cat/9841.png
# Download 9752.png to data/cifar-10/train/cat/9752.png
# Download 11205.png to data/cifar-10/train/cat/11205.png
# Download 10653.png to data/cifar-10/train/cat/10653.png
# Download 10506.png to data/cifar-10/train/cat/10506.png
# Download 10430.png to data/cifar-10/train/cat/10430.png
# Download 10320.png to data/cifar-10/train/cat/10320.png
# Download 10788.png to data/cifar-10/train/cat/10788.png
# Download 10182.png to data/cifar-10/train/cat/10182.png
# Download 9912.png to data/cifar-10/train/cat/9912.png
# Download 10322.png to data/cifar-10/train/cat/10322.png
# Download 9856.png to data/cifar-10/train/cat/9856.png
# Download 10021.png to data/cifar-10/train/cat/10021.png
# Download 10192.png to data/cifar-10/train/cat/10192.png
# Download 11040.png to data/cifar-10/train/cat/11040.png
# Download 10310.png to data/cifar-10/train/cat/10310.png
# Download 11188.png to data/cifar-10/train/cat/11188.png
# Download 10967.png to data/cifar-10/train/cat/10967.png
# Download 11344.png to data/cifar-10/train/cat/11344.png
# Download 10619.png to data/cifar-10/train/cat/10619.png
# Download 10518.png to data/cifar-10/train/cat/10518.png
# Download 9909.png to data/cifar-10/train/cat/9909.png
# Download 11055.png to data/cifar-10/train/cat/11055.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 download_file_recursively( folder_id, 'data')
#
# Cell In [17], line 8, in download_file_recursively(parent_id, dst_dir)
#       6 for f in file_list:
#       7     if f['mimeType'] == 'application/vnd.google-apps.folder':
# ----> 8         download_file_recursively( f['id'], os.path.join(dst_dir, f['title']))
#       9     else:
#      10         dst_path = os.path.join(dst_dir, f['title'])
#
# Cell In [17], line 8, in download_file_recursively(parent_id, dst_dir)
#       6 for f in file_list:
#       7     if f['mimeType'] == 'application/vnd.google-apps.folder':
# ----> 8         download_file_recursively( f['id'], os.path.join(dst_dir, f['title']))
#       9     else:
#      10         dst_path = os.path.join(dst_dir, f['title'])
#
# Cell In [17], line 8, in download_file_recursively(parent_id, dst_dir)
#       6 for f in file_list:
#       7     if f['mimeType'] == 'application/vnd.google-apps.folder':
# ----> 8         download_file_recursively( f['id'], os.path.join(dst_dir, f['title']))
#       9     else:
#      10         dst_path = os.path.join(dst_dir, f['title'])
#
# Cell In [17], line 11, in download_file_recursively(parent_id, dst_dir)
#       9 else:
#      10     dst_path = os.path.join(dst_dir, f['title'])
# ---> 11     f.GetContentFile(dst_path)
#      12     print('Download {} to {}'.format(f['title'], dst_path))
#
# File /usr/local/lib/python3.10/site-packages/pydrive/files.py:210, in GoogleDriveFile.GetContentFile(self, filename, mimetype, remove_bom)
#     197 """Save content of this file as a local file.
#     198
#     199 :param filename: name of the file to write to.
#    (...)
#     205 :raises: ApiRequestError, FileNotUploadedError, FileNotDownloadableError
#     206 """
#     207 if self.content is None or \
#     208                 type(self.content) is not io.BytesIO or \
#     209                 self.has_bom == remove_bom:
# --> 210   self.FetchContent(mimetype, remove_bom)
#     211 f = open(filename, 'wb')
#     212 f.write(self.content.getvalue())
#
# File /usr/local/lib/python3.10/site-packages/pydrive/files.py:43, in LoadMetadata.<locals>._decorated(self, *args, **kwargs)
#      41 if not self.uploaded:
#      42   self.FetchMetadata()
# ---> 43 return decoratee(self, *args, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/pydrive/files.py:255, in GoogleDriveFile.FetchContent(self, mimetype, remove_bom)
#     253 export_links = self.metadata.get('exportLinks')
#     254 if download_url:
# --> 255   self.content = io.BytesIO(self._DownloadFromUrl(download_url))
#     256   self.dirty['content'] = False
#     258 elif export_links and export_links.get(mimetype):
#
# File /usr/local/lib/python3.10/site-packages/pydrive/auth.py:75, in LoadAuth.<locals>._decorated(self, *args, **kwargs)
#      72 else:  # If HTTP object not specified, each call creates new HTTP object.
#      73   self.http = self.auth.Get_Http_Object()
# ---> 75 return decoratee(self, *args, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/pydrive/files.py:503, in GoogleDriveFile._DownloadFromUrl(self, url)
#     494 @LoadAuth
#     495 def _DownloadFromUrl(self, url):
#     496   """Download file from url using provided credential.
#     497
#     498   :param url: link of the file to download.
#    (...)
#     501   :raises: ApiRequestError
#     502   """
# --> 503   resp, content = self.http.request(url)
#     504   if resp.status != 200:
#     505     raise ApiRequestError('Cannot download file: %s' % resp)
#
# File /usr/local/lib/python3.10/site-packages/oauth2client/transport.py:173, in wrap_http_for_auth.<locals>.new_request(uri, method, body, headers, redirections, connection_type)
#     169 if all(getattr(body, stream_prop, None) for stream_prop in
#     170        _STREAM_PROPERTIES):
#     171     body_stream_position = body.tell()
# --> 173 resp, content = request(orig_request_method, uri, method, body,
#     174                         clean_headers(headers),
#     175                         redirections, connection_type)
#     177 # A stored token may expire between the time it is retrieved and
#     178 # the time the request is made, so we may need to try twice.
#     179 max_refresh_attempts = 2
#
# File /usr/local/lib/python3.10/site-packages/oauth2client/transport.py:280, in request(http, uri, method, body, headers, redirections, connection_type)
#     278 # NOTE: Allowing http or http.request is temporary (See Issue 601).
#     279 http_callable = getattr(http, 'request', http)
# --> 280 return http_callable(uri, method=method, body=body, headers=headers,
#     281                      redirections=redirections,
#     282                      connection_type=connection_type)
#
# File /usr/local/lib/python3.10/site-packages/httplib2/__init__.py:1701, in Http.request(self, uri, method, body, headers, redirections, connection_type)
#    1699             content = b""
#    1700         else:
# -> 1701             (response, content) = self._request(
#    1702                 conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1703             )
#    1704 except Exception as e:
#    1705     is_timeout = isinstance(e, socket.timeout)
#
# File /usr/local/lib/python3.10/site-packages/httplib2/__init__.py:1421, in Http._request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1418 if auth:
#    1419     auth.request(method, request_uri, headers, body)
# -> 1421 (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1423 if auth:
#    1424     if auth.response(response, body):
#
# File /usr/local/lib/python3.10/site-packages/httplib2/__init__.py:1373, in Http._conn_request(self, conn, request_uri, method, body, headers)
#    1371     pass
#    1372 try:
# -> 1373     response = conn.getresponse()
#    1374 except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1375     # If we get a BadStatusLine on the first try then that means
#    1376     # the connection just went stale, so retry regardless of the
#    1377     # number of RETRIES set.
#    1378     if not seen_bad_status_line and i == 1:
#
# File /usr/local/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /usr/local/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/local/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/local/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/local/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
